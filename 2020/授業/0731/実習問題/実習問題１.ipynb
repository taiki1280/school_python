# %% [markdown]
# ## Pythonのオブジェクト指向プログラミング実習問題

# %% [markdown]
# ## 問題１
# 下記のクラス図と実行結果尾を参考にプログラムを完成させてください。

# %% [markdown]
# ### クラス図
# <img src="ex_object7.png">

# %% [markdown]
# ### 実行結果
# <img src="ex_object7_run.png">

# %%
# abcパッケージのインポート
from abc import ABCMeta
from abc import abstractmethod

# %%
# 物体の表面積と体積を計算する抽象クラス（Dimentionクラス）の定義

  # コンストラクタ定義
  '''
  _side: float（物体の辺の長さ）アクセス属性：protected
  '''
  
    
  # ゲッター定義
  # sideゲッター
    
    

  # 表面積を計算する抽象メソッドの定義
  '''
  メソッドシグニチャ
    メソッド名：area
    引数：なし
    処理：物体の表面積を計算して返す
    戻り値：物体の表面積（型 float）
  '''

    
  # 体積を計算する抽象メソッドの定義
  '''
  メソッドシグニチャ
    メソッド名：area
    引数：side: float（辺の長さ）アクセス属性：protected
    処理：物体の体積を計算して返す
    戻り値：物体の体積（型 float）
  '''

# %%
# 球体の表面積と体積を計算するクラス（Sphereクラス）の定義
# 抽象クラス Dimention を継承

  # コンストラクタ定義
  '''
  _side: float（球体の半径）アクセス属性：protected
  '''
  
    

  # 球体の表面積を計算するメソッド area の実装
  # 球体の表面積 = 4.0 * 3.14 * 半径の２乗
  
    

  # 球体の体積を計算するメソッドの定義
  # 球体の体積 = 4.0 * 3.14 * 半径の３乗 / 3.0

# %%
# 立方体の表面積と体積を計算するクラス（Cubeクラス）の定義
# 抽象クラス Dimention を継承

  # コンストラクタ定義
  '''
  _side: float（立方体の辺）アクセス属性：protected
  '''
  
    

  # 立方体の表面積を計算するメソッド area の実装
  # 立方体の表面積 = 6.0 * １辺の２乗
  
    

  # 立方体の体積を計算するメソッドの定義
  # 立方体の体積 = １辺の３乗

# %% [markdown]
# ## 問題２
# 下記のクラス図と実行結果尾を参考にプログラムを完成させてください。

# %% [markdown]
# ### クラス図
