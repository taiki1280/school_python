# %% [markdown]
# ## 問題２
# 下記のクラス図と実行結果尾を参考にプログラムを完成させてください。

# %% [markdown]
# ### クラス図
# <img src="ex_object8.png">

# %% [markdown]
# ### 実行結果
# <img src="ex_object8_run.png">

# %% [markdown]
# ### CarToyクラス定義

# %%
  # コンストラクタ定義
  
    

  # ゲッター定義
  # codeゲッター
  



  # priceゲッター
  



  # セッター定義
  # codeセッター
 
    

  # priceセッター
  
    

  # 走るメソッド（goメソッド）定義
  
    
  # ライトをつけるメソッド（lightメソッド）定義

# %% [markdown]
# ### PatrolCarToyクラス定義

# %%
  # コンストラクタ定義
  


  # 走るメソッド（goメソッド）定義（オーバーライド）
  


  # サイレンを鳴らすメソッド（sirenメソッド）定義

# %% [markdown]
# ### TrainToyクラス定義

# %%
  # コンストラクタ定義
  
    

  # ゲッター定義
  # codeゲッター
  


  # priceゲッター
  


  # セッター定義
  # codeセッター
  
    

  # priceセッター
  
    

  # 走るメソッド（goメソッド）定義
  
    

  # 警笛を鳴らすメソッド（hornメソッド）定義

# %% [markdown]
# ### ShopKeeperクラス定義

# %%
  # コンストラクタ定義
 


  # 価格チェックメソッド（checkメソッド）定義
  




  # おもちゃのデモメソッド（doDemoメソッド）定義

# %% [markdown]
# ### 実行プログラム

# %%
keeper = ShopKeeper('鈴木一朗')
car = CarToy('CARTOY0001', 1800)
pcar = PatrolCarToy('PATROLTOY0001', 3500)
train = TrainToy('TRAINTOY0001', 4800)
#
keeper.check(car, pcar, train)
keeper.doDemo(car, pcar, train)
